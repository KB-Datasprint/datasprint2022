# %% [markdown]
# # Use Python to identify the language of a text
#
# Using the library `langdetect` we can easily identify the language of a text with relatively high precision.
#
# If `langdetect` is not installed, we can install it with `!pip install langdetect`.
#
# We specifically import the `detect` function from `langdetect`. We also import `pandas` to handle the dataset.

# %%
from langdetect import detect
import pandas as pd

# %% [markdown]
# The `detect` function simply takes a text string as its input and returns the detected language.

# %%
detect('This text is in English')
# Out:
# 'en'

# %%
detect('Dette er et andet sprog')
# Out:
# 'no'

# %% [markdown]
# In order to apply the function to our data, we load the data into a DataFrame using the `read_csv` function from `pandas`.

# %%
df = pd.read_csv('data/cookies.csv')

# %% [markdown]
# Using the `apply` method, we can *apply* the function to each row of the DataFrame. `axis=1` tells Python to apply the function to the rows instead of the columns.

# %%
df['desc_lan'] = df.apply(lambda row: detect(row['description']), axis=1)

# %% [markdown]
# We now have a new column in the DataFrame, which we can summarise with `value_counts`.

# %%
df.value_counts('desc_lan')
# Out:
# desc_lan
# da    554
# en    129
# af     32
# id     29
# fr      2
# nl      2
# ca      1
# pl      1
# dtype: int64

# %% [markdown]
# As expected, most of the descriptions are in Danish or English. However, we get some suspicious values such as Afrikaans, Indonesian and Catalan. If we inspect the texts we find that they are most likely misclassified due to sparse input.

# %%
df[df['desc_lan'] == 'af']
# Out:
#                                  name           provider           origin  \
# 9    fp_last_login_adjustment_attempt    Jyllands-posten  jyllands-posten
# 13            last_login_event_source    Jyllands-posten  jyllands-posten
# 14              last_login_event_time    Jyllands-posten  jyllands-posten
# 15              last_login_event_type    Jyllands-posten  jyllands-posten
# 29                           _c_ [x3]    Jyllands-posten  jyllands-posten
# 33      keesing-last-created-storages    Jyllands-posten  jyllands-posten
# 34              keesing-unique-userid    Jyllands-posten  jyllands-posten
# 56                              ssoid    Jyllands-posten  jyllands-posten
# 63                  instapage-visit-#       g.fastcdn.co  jyllands-posten
# 95               __tea_cache_tokens_#             Tiktok  jyllands-posten
# 117                            __cmp#    Jyllands-posten  jyllands-posten
# 118                      customerHash    Jyllands-posten  jyllands-posten
# 119                   vouchers-filter    Jyllands-posten  jyllands-posten
# 120                        ip-sp-mode    Jyllands-posten  jyllands-posten
# 139                              _gd#   Berlingske Media               bt
# 162                                 p  ScorecardResearch               bt
# 173                           #_#_gig   Berlingske Media               bt
# 199                              v1st        Dailymotion               bt
# 200                   behavior/GUID/#        Dailymotion               bt
# 254                              v1st        Dailymotion        politiken
# 263             OpenIdConnect.nonce.#          Politiken        politiken
# 270                               _ls          Politiken        politiken
# 277    pol.fonts.FlamaBold.84308fd8ca          Politiken        politiken
# 284                      _#/redot.gif             Gemius        politiken
# 292                   pol_org_content          Politiken        politiken
# 308                              ping          Chartbeat        politiken
# 335                           maincat          Politiken        politiken
# 349                          __ur_ttl         UserReport        politiken
# 416                              _gd#   Berlingske Media       berlingske
# 420                      _#/redot.gif             Gemius       berlingske
# 437                           #_#_gig   Berlingske Media       berlingske
# 526             jwplayer.captionLabel   Berlingske Media       berlingske
#
#      expiration    duration   type description  \
# 9       Session         NaN   HTTP    Afventer
# 13      Session         NaN   HTTP    Afventer
# 14      Session         NaN   HTTP    Afventer
# 15      Session         NaN   HTTP    Afventer
# 29      Session         NaN   HTTP    Afventer
# 33   Persistent         NaN   HTML    Afventer
# 34   Persistent         NaN   HTML    Afventer
# 56   Persistent         NaN   HTML    Afventer
# 63   Persistent         NaN   HTML    Afventer
# 95   Persistent         NaN   HTML    Afventer
# 117     13 dage   1123200.0   HTTP    Afventer
# 118        1 år  31557600.0   HTTP    Afventer
# 119  Persistent         NaN   HTML    Afventer
# 120  Persistent         NaN   HTML    Afventer
# 139     Session         NaN   HTTP    Afventer
# 162     Session         NaN  Pixel    Afventer
# 173  Persistent         NaN   HTML    Afventer
# 199        1 år  31557600.0   HTTP    Afventer
# 200     Session         NaN  Pixel    Afventer
# 254        1 år  31557600.0   HTTP    Afventer
# 263       1 dag     86400.0   HTTP    Afventer
# 270        1 år  31557600.0   HTML    Afventer
# 277  Persistent         NaN   HTML    Afventer
# 284     Session         NaN  Pixel    Afventer
# 292     Session         NaN   HTML    Afventer
# 308     Session         NaN  Pixel    Afventer
# 335     Session         NaN   HTML    Afventer
# 349        1 år  31557600.0   HTTP    Afventer
# 416     Session         NaN   HTTP    Afventer
# 420     Session         NaN  Pixel    Afventer
# 437  Persistent         NaN   HTML    Afventer
# 526  Persistent         NaN   HTML    Afventer
#
#                                            policy_link  \
# 9           https://www.jyllands-posten.dk/om/cookies/
# 13          https://www.jyllands-posten.dk/om/cookies/
# 14          https://www.jyllands-posten.dk/om/cookies/
# 15          https://www.jyllands-posten.dk/om/cookies/
# 29          https://www.jyllands-posten.dk/om/cookies/
# 33          https://www.jyllands-posten.dk/om/cookies/
# 34          https://www.jyllands-posten.dk/om/cookies/
# 56          https://www.jyllands-posten.dk/om/cookies/
# 63                                                 NaN
# 95   https://www.tiktok.com/legal/privacy-policy?la...
# 117         https://www.jyllands-posten.dk/om/cookies/
# 118         https://www.jyllands-posten.dk/om/cookies/
# 119         https://www.jyllands-posten.dk/om/cookies/
# 120         https://www.jyllands-posten.dk/om/cookies/
# 139  https://www.berlingskemedia.dk/cookie-og-priva...
# 162  http://www.scorecardresearch.com/privacy.aspx?...
# 173  https://www.berlingskemedia.dk/cookie-og-priva...
# 199  https://www.dailymotion.com/legal/privacy?loca...
# 200  https://www.dailymotion.com/legal/privacy?loca...
# 254  https://www.dailymotion.com/legal/privacy?loca...
# 263  https://politiken.dk/om_politiken/art4951194/P...
# 270  https://politiken.dk/om_politiken/art4951194/P...
# 277  https://politiken.dk/om_politiken/art4951194/P...
# 284     http://www.gemius.pl/polityka-prywatnosci.html
# 292  https://politiken.dk/om_politiken/art4951194/P...
# 308                     https://chartbeat.com/privacy/
# 335  https://politiken.dk/om_politiken/art4951194/P...
# 349  https://privacy.userreport.com/en-GB/for-users...
# 416  https://www.berlingskemedia.dk/cookie-og-priva...
# 420     http://www.gemius.pl/polityka-prywatnosci.html
# 437  https://www.berlingskemedia.dk/cookie-og-priva...
# 526  https://www.berlingskemedia.dk/cookie-og-priva...
#
#                                            policy_text desc_lan
# 9    tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 13   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 14   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 15   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 29   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 33   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 34   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 56   tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 63                                                 NaN       af
# 95   TikTokSelect regionU.S.If you live in the Unit...       af
# 117  tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 118  tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 119  tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 120  tirsdag 11. oktober 2022 Log ind Log ud Køb Me...       af
# 139  Cookie- og privatlivspolitik1. december 20201....       af
# 162  English | Español | Nederlands | Svenska | Por...       af
# 173  Cookie- og privatlivspolitik1. december 20201....       af
# 199  Home Legal Terms Terms Of Use Legal Notices Pr...       af
# 200  Home Legal Terms Terms Of Use Legal Notices Pr...       af
# 254  Home Legal Terms Terms Of Use Legal Notices Pr...       af
# 263  0 Læs nu Du har ingen artikler på din læselist...       af
# 270  0 Læs nu Du har ingen artikler på din læselist...       af
# 277  0 Læs nu Du har ingen artikler på din læselist...       af
# 284  Menu Przeszukaj treści według wybranego tematu...       af
# 292  0 Læs nu Du har ingen artikler på din læselist...       af
# 308  Opens in a new window Opens an external websit...       af
# 335  0 Læs nu Du har ingen artikler på din læselist...       af
# 349  Privacy PortalFor usersPrivacy policyOpt-out a...       af
# 416  Cookie- og privatlivspolitik1. december 20201....       af
# 420  Menu Przeszukaj treści według wybranego tematu...       af
# 437  Cookie- og privatlivspolitik1. december 20201....       af
# 526  Cookie- og privatlivspolitik1. december 20201....       af

# %% [markdown]
# Similarly, we can detect the language of the cookie policy texts. As these are generally longer texts, the `detect` function should be able to perform better. However, some policy texts are missing in the dataset and we have to account for that when we apply the function.

# %%
df['policy_lan'] = df.apply(lambda row: detect(row['policy_text']) if isinstance(row['policy_text'], str) else None, axis=1)

# %% [markdown]
# If we count the values again, the classifications seem to be more precise.

# %%
df.value_counts('policy_lan')
# Out:
# policy_lan
# en    408
# da    243
# pl     25
# de      2
# fr      1
# dtype: int64

# %% [markdown]
# Now we can subset our data based on language, which is very useful when we start analysing the text.
#
# For instance, we can create a DataFrame with English policy texts and a DataFrame with Danish policy texts.

# %%
en_df = df[df['policy_lan'] == 'en']

da_df = df[df['policy_lan'] == 'da']

# %% [markdown]
# We now have two smaller and cleaner datasets which are easier to proceed with if we want to analyse the content of the policies.
